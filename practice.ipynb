# %%
print("데이터 분석 준비 완료!")
# Out:
# 데이터 분석 준비 완료!

# %%
import pandas as pd

data = {
    '사원이름' : ['강승균', '김철수', '이영희'],
    '부서' : ['빅데이터팀', '회계팀', '인사팀'],
    '직급' : ['사원', '대리', '과장']
}
df = pd.DataFrame(data)
df
# Out:
#   사원이름     부서  직급
# 0  강승균  빅데이터팀  사원
# 1  김철수    회계팀  대리
# 2  이영희    인사팀  과장
